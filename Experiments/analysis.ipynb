# %%
import pandas as pd
import numpy as np
from glob import glob
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
def bootstrap_performance(y_true, y_pred, sample_size=500, n_samples=100):
    assert len(y_true) == len(y_pred), "Both lists must be of same length"
    n = len(y_true)
    accuracies = []
    f1s = []

    for seed_val in range(n_samples):
        # Sample indices with replacement
        np.random.seed(seed_val)
        indices = np.random.choice(len(y_true), size=sample_size, replace=False)
        sample_true = [y_true[i] for i in indices]
        sample_pred = [y_pred[i] for i in indices]
        acc = accuracy_score(sample_true, sample_pred)
        accuracies.append(acc)
        f1 = f1_score(sample_true, sample_pred, average='weighted')
        f1s.append(f1)

    return np.mean(accuracies), np.std(accuracies), np.mean(f1s), np.std(f1s)

def analyze_results(tru, pred):
    accuracy = accuracy_score(tru, pred)
    f1 = f1_score(tru, pred, average='weighted')
    report = classification_report(tru, pred, digits=6)
    
    print(f"Overall Accuracy: {accuracy:.6f}")
    print(f"Overall w-F1 Score: {f1:.6f}")
    print("Overall Classification Report:")
    print(report)

    # Mean and standard deviation of the predictions performance scores
    mean_acc, std_acc, mean_f1, std_f1 = bootstrap_performance(tru, pred)
    print(f"Bootstrapped Accuracy: {mean_acc:.6f} ± {std_acc:.6f}")
    print(f"Bootstrapped w-F1 Score: {mean_f1:.6f} ± {std_f1:.6f}")

# %%
files = glob("Outputs/*.csv")
files.sort()

for f in files:
    print(f"Analyzing file: {f}")
    df = pd.read_csv(f)
    tru = df['true_label'].tolist()
    pred = df['predicted_label'].tolist()

    # Analyze the results
    analyze_results(tru, pred)
    print("\n" + "="*50 + "\n")
# Out:
# Analyzing file: Outputs/albert-base-v2_isExt_0.csv
# Overall Accuracy: 0.585667
# Overall w-F1 Score: 0.550835
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.610047  0.814205  0.697493      1760
#            1   0.497696  0.261290  0.342676      1240
#
#     accuracy                       0.585667      3000
#    macro avg   0.553871  0.537747  0.520085      3000
# weighted avg   0.563608  0.585667  0.550835      3000
#
# Bootstrapped Accuracy: 0.584840 ± 0.018692
# Bootstrapped w-F1 Score: 0.549638 ± 0.021041
#
# ==================================================
#
# Analyzing file: Outputs/albert-base-v2_isExt_1.csv
# Overall Accuracy: 0.583667
# Overall w-F1 Score: 0.585280
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.651812  0.623295  0.637235      1760
#            1   0.496583  0.527419  0.511537      1240
#
#     accuracy                       0.583667      3000
#    macro avg   0.574198  0.575357  0.574386      3000
# weighted avg   0.587651  0.583667  0.585280      3000
# Bootstrapped Accuracy: 0.583880 ± 0.019041
# Bootstrapped w-F1 Score: 0.585389 ± 0.019137
#
# ==================================================
#
# Analyzing file: Outputs/beit-base-patch16-224-pt22k-ft22k_isExt_0.csv
# Overall Accuracy: 0.578333
# Overall w-F1 Score: 0.533886
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.601810  0.831250  0.698163      1760
#            1   0.478032  0.219355  0.300719      1240
#
#     accuracy                       0.578333      3000
#    macro avg   0.539921  0.525302  0.499441      3000
# weighted avg   0.550648  0.578333  0.533886      3000
#
# Bootstrapped Accuracy: 0.578680 ± 0.020800
# Bootstrapped w-F1 Score: 0.533802 ± 0.023876
#
# ==================================================
#
# Analyzing file: Outputs/beit-base-patch16-224-pt22k-ft22k_isExt_1.csv
# Overall Accuracy: 0.586333
# Overall w-F1 Score: 0.555622
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.612484  0.802841  0.694861      1760
#            1   0.499278  0.279032  0.357993      1240
#
#     accuracy                       0.586333      3000
#    macro avg   0.555881  0.540937  0.526427      3000
# weighted avg   0.565692  0.586333  0.555622      3000
#
# Bootstrapped Accuracy: 0.585640 ± 0.022493
# Bootstrapped w-F1 Score: 0.554275 ± 0.024641
#
# ==================================================
#
# Analyzing file: Outputs/bert-base-uncased_isExt_0.csv
# Overall Accuracy: 0.589000
# Overall w-F1 Score: 0.553848
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.611890  0.818750  0.700365      1760
#            1   0.505426  0.262903  0.345889      1240
#
#     accuracy                       0.589000      3000
#    macro avg   0.558658  0.540827  0.523127      3000
# weighted avg   0.567885  0.589000  0.553848      3000
#
# Bootstrapped Accuracy: 0.590820 ± 0.019539
# Bootstrapped w-F1 Score: 0.555022 ± 0.022619
#
# ==================================================
#
# Analyzing file: Outputs/bert-base-uncased_isExt_1.csv
# Overall Accuracy: 0.579667
# Overall w-F1 Score: 0.577497
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.635967  0.663068  0.649235      1760
#            1   0.490987  0.461290  0.475676      1240
#
#     accuracy                       0.579667      3000
#    macro avg   0.563477  0.562179  0.562455      3000
# weighted avg   0.576042  0.579667  0.577497      3000
#
# Bootstrapped Accuracy: 0.581980 ± 0.020460
# Bootstrapped w-F1 Score: 0.579472 ± 0.020826
#
# ==================================================
#
# Analyzing file: Outputs/clip-vit-base-patch32_isExt_0.csv
# Overall Accuracy: 0.584333
# Overall w-F1 Score: 0.478390
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.591119  0.945455  0.727432      1760
#            1   0.481081  0.071774  0.124912      1240
#
#     accuracy                       0.584333      3000
#    macro avg   0.536100  0.508614  0.426172      3000
# weighted avg   0.545637  0.584333  0.478390      3000
#
# Bootstrapped Accuracy: 0.583400 ± 0.018790
# Bootstrapped w-F1 Score: 0.477125 ± 0.023668
#
# ==================================================
#
# Analyzing file: Outputs/clip-vit-base-patch32_isExt_1.csv
# Overall Accuracy: 0.587000
# Overall w-F1 Score: 0.520558
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.600077  0.887500  0.716021      1760
#            1   0.501259  0.160484  0.243128      1240
#
#     accuracy                       0.587000      3000
#    macro avg   0.550668  0.523992  0.479574      3000
# weighted avg   0.559232  0.587000  0.520558      3000
#
# Bootstrapped Accuracy: 0.585600 ± 0.020611
# Bootstrapped w-F1 Score: 0.517693 ± 0.024097
#
# ==================================================
#
# Analyzing file: Outputs/deit-base-patch16-224_isExt_0.csv
# Overall Accuracy: 0.559333
# Overall w-F1 Score: 0.526119
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.594723  0.781250  0.675344      1760
#            1   0.440407  0.244355  0.314315      1240
#
#     accuracy                       0.559333      3000
#    macro avg   0.517565  0.512802  0.494830      3000
# weighted avg   0.530939  0.559333  0.526119      3000
#
# Bootstrapped Accuracy: 0.560120 ± 0.022905
# Bootstrapped w-F1 Score: 0.525849 ± 0.024557
#
# ==================================================
#
# Analyzing file: Outputs/deit-base-patch16-224_isExt_1.csv
# Overall Accuracy: 0.577333
# Overall w-F1 Score: 0.520657
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.597387  0.857386  0.704153      1760
#            1   0.470464  0.179839  0.260210      1240
#
#     accuracy                       0.577333      3000
#    macro avg   0.533926  0.518613  0.482182      3000
# weighted avg   0.544926  0.577333  0.520657      3000
#
# Bootstrapped Accuracy: 0.577220 ± 0.020038
# Bootstrapped w-F1 Score: 0.519893 ± 0.022560
#
# ==================================================
#
# Analyzing file: Outputs/roberta-base_isExt_0.csv
# Overall Accuracy: 0.589667
# Overall w-F1 Score: 0.472386
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.592128  0.965909  0.734183      1760
#            1   0.534884  0.055645  0.100804      1240
#
#     accuracy                       0.589667      3000
#    macro avg   0.563506  0.510777  0.417493      3000
# weighted avg   0.568467  0.589667  0.472386      3000
#
# Bootstrapped Accuracy: 0.589380 ± 0.019587
# Bootstrapped w-F1 Score: 0.471775 ± 0.023943
#
# ==================================================
#
# Analyzing file: Outputs/roberta-base_isExt_1.csv
# Overall Accuracy: 0.572667
# Overall w-F1 Score: 0.527503
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.598273  0.826705  0.694179      1760
#            1   0.463028  0.212097  0.290929      1240
#
#     accuracy                       0.572667      3000
#    macro avg   0.530651  0.519401  0.492554      3000
# weighted avg   0.542372  0.572667  0.527503      3000
#
# Bootstrapped Accuracy: 0.570980 ± 0.019579
# Bootstrapped w-F1 Score: 0.525383 ± 0.021594
#
# ==================================================
#
# Analyzing file: Outputs/vit-base-patch16-224_isExt_0.csv
# Overall Accuracy: 0.562333
# Overall w-F1 Score: 0.528845
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.596461  0.785227  0.677949      1760
#            1   0.446559  0.245968  0.317213      1240
#
#     accuracy                       0.562333      3000
#    macro avg   0.521510  0.515598  0.497581      3000
# weighted avg   0.534502  0.562333  0.528845      3000
#
# Bootstrapped Accuracy: 0.565620 ± 0.018430
# Bootstrapped w-F1 Score: 0.532841 ± 0.020080
#
# ==================================================
#
# Analyzing file: Outputs/vit-base-patch16-224_isExt_1.csv
# Overall Accuracy: 0.584333
# Overall w-F1 Score: 0.533972
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#            0   0.603219  0.851705  0.706243      1760
#            1   0.493204  0.204839  0.289459      1240
#
#     accuracy                       0.584333      3000
#    macro avg   0.548212  0.528272  0.497851      3000
# weighted avg   0.557746  0.584333  0.533972      3000
#
# Bootstrapped Accuracy: 0.585640 ± 0.021448
# Bootstrapped w-F1 Score: 0.535808 ± 0.024572
#
# ==================================================
